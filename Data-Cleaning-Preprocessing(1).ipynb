# %%
import pandas as pd 
import numpy as np

# %%
# !pip install xlrd==1.2.0
# Out:
# Requirement already satisfied: xlrd==1.2.0 in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (1.2.0)

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
# %pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/amodpathirana/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df =pd.read_excel("website_visitors.xlsx")

# %%
df.head()
# Out:
#    customer_id                 date  age  gender country  item purchased  \
# 0            1  2022-03-02 00:00:00   23    Male      US             2.0
# 1            2  2022-03-03 00:00:00   34  Female   India             5.0
# 2            3  2022-03-04 00:00:00   23    Male     NaN             2.0
# 3            4  2022-03-05 00:00:00  ERR    Male      UK             7.0
# 4            5  2021-03-23 00:00:00   23    Male  France             1.0
#
#    value monthly visits
# 0    258            234
# 1    645            567
# 2    258            123
# 3    903            123
# 4    129             47

# %%
df.shape
# Out:
# (30, 8)

# %% [markdown]
# # Data quality checking

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     30 non-null     int64
#  1   date            30 non-null     object
#  2   age             27 non-null     object
#  3   gender          29 non-null     object
#  4   country         29 non-null     object
#  5   item purchased  29 non-null     float64
#  6   value           30 non-null     int64
#  7   monthly visits  27 non-null     object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.0+ KB

# %%
df['country'].unique()
# Out:
# array(['US', 'India', nan, 'UK', 'France', 'Bolivia', 'Sweden', 'USA',
#        'Germany', 'Brazil', 'Chile', 'Saudi Arabia', 'Japan', 'Norway',
#        'Spain', 'Nigeria', 'United Kingdom', 'Switzerland', 'Russia'],
#       dtype=object)

# %%
df['country'].nunique()
# Out:
# 18

# %%
df.isna().sum()
# Out:
# customer_id       0
# date              0
# age               3
# gender            1
# country           1
# item purchased    1
# value             0
# monthly visits    3
# dtype: int64

# %%
(df.isna().sum()*100)/len(df)
# Out:
# customer_id        0.000000
# date               0.000000
# age               10.000000
# gender             3.333333
# country            3.333333
# item purchased     3.333333
# value              0.000000
# monthly visits    10.000000
# dtype: float64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, date, age, gender, country, item purchased, value, monthly visits]
# Index: []

# %% [markdown]
# # Data cleaning and Preprocessing

# %%
df.head(20)
# Out:
#     customer_id                 date  age  gender       country  \
# 0             1  2022-03-02 00:00:00   23    Male            US
# 1             2  2022-03-03 00:00:00   34  Female         India
# 2             3  2022-03-04 00:00:00   23    Male           NaN
# 3             4  2022-03-05 00:00:00  ERR    Male            UK
# 4             5  2021-03-23 00:00:00   23    Male        France
# 5             6  2022-03-07 00:00:00  NaN    Male       Bolivia
# 6             7  2022-03-08 00:00:00   27    Male        Sweden
# 7             8  2021-02-02 00:00:00   23    Male           USA
# 8             9  2022-03-10 00:00:00   29  Female       Germany
# 9            10  2022-03-11 00:00:00   21    Male       Germany
# 10           11  2022-03-12 00:00:00  NaN    Male        Brazil
# 11           12  2022-03-13 00:00:00   31  Female           USA
# 12           13  2022-03-14 00:00:00   32    Male         India
# 13           14              3-15-21   27    Male         Chile
# 14           15  2022-03-16 00:00:00   23  Female  Saudi Arabia
# 15           16  2022-03-17 00:00:00   26    Male         India
# 16           17  2022-03-18 00:00:00   29  Female         Chile
# 17           18  2022-03-19 00:00:00  ERR    Male  Saudi Arabia
# 18           19  2022-03-20 00:00:00   35    Male         India
# 19           20  2022-03-21 00:00:00   38  Female            US
#
#     item purchased  value monthly visits
# 0              2.0    258            234
# 1              5.0    645            567
# 2              2.0    258            123
# 3              7.0    903            123
# 4              1.0    129             47
# 5              9.0   1161              3
# 6              2.0    258            557
# 7              1.0    129            455
# 8              2.0    258            NaN
# 9              6.0    774            554
# 10             5.0    645            397
# 11             4.0    516            567
# 12             2.0    258            347
# 13             3.0    387            NaN
# 14             6.0    774            582
# 15             7.0    903            234
# 16             9.0   1161            ERR
# 17             1.0    129            234
# 18             6.0    774            478
# 19             2.0    258            490

# %%
df=df.replace('ERR', np.nan)

# %%
df.head(20)
# Out:
#     customer_id                 date   age  gender       country  \
# 0             1  2022-03-02 00:00:00  23.0    Male            US
# 1             2  2022-03-03 00:00:00  34.0  Female         India
# 2             3  2022-03-04 00:00:00  23.0    Male           NaN
# 3             4  2022-03-05 00:00:00   NaN    Male            UK
# 4             5  2021-03-23 00:00:00  23.0    Male        France
# 5             6  2022-03-07 00:00:00   NaN    Male       Bolivia
# 6             7  2022-03-08 00:00:00  27.0    Male        Sweden
# 7             8  2021-02-02 00:00:00  23.0    Male           USA
# 8             9  2022-03-10 00:00:00  29.0  Female       Germany
# 9            10  2022-03-11 00:00:00  21.0    Male       Germany
# 10           11  2022-03-12 00:00:00   NaN    Male        Brazil
# 11           12  2022-03-13 00:00:00  31.0  Female           USA
# 12           13  2022-03-14 00:00:00  32.0    Male         India
# 13           14              3-15-21  27.0    Male         Chile
# 14           15  2022-03-16 00:00:00  23.0  Female  Saudi Arabia
# 15           16  2022-03-17 00:00:00  26.0    Male         India
# 16           17  2022-03-18 00:00:00  29.0  Female         Chile
# 17           18  2022-03-19 00:00:00   NaN    Male  Saudi Arabia
# 18           19  2022-03-20 00:00:00  35.0    Male         India
# 19           20  2022-03-21 00:00:00  38.0  Female            US
#
#     item purchased  value  monthly visits
# 0              2.0    258           234.0
# 1              5.0    645           567.0
# 2              2.0    258           123.0
# 3              7.0    903           123.0
# 4              1.0    129            47.0
# 5              9.0   1161             3.0
# 6              2.0    258           557.0
# 7              1.0    129           455.0
# 8              2.0    258             NaN
# 9              6.0    774           554.0
# 10             5.0    645           397.0
# 11             4.0    516           567.0
# 12             2.0    258           347.0
# 13             3.0    387             NaN
# 14             6.0    774           582.0
# 15             7.0    903           234.0
# 16             9.0   1161             NaN
# 17             1.0    129           234.0
# 18             6.0    774           478.0
# 19             2.0    258           490.0

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy="mean")

df[['value', 'item purchased','monthly visits']] = imputer.fit_transform(df[['value', 'item purchased','monthly visits']])

# %%
df.head(20)
# Out:
#     customer_id                 date   age  gender       country  \
# 0             1  2022-03-02 00:00:00  23.0    Male            US
# 1             2  2022-03-03 00:00:00  34.0  Female         India
# 2             3  2022-03-04 00:00:00  23.0    Male           NaN
# 3             4  2022-03-05 00:00:00   NaN    Male            UK
# 4             5  2021-03-23 00:00:00  23.0    Male        France
# 5             6  2022-03-07 00:00:00   NaN    Male       Bolivia
# 6             7  2022-03-08 00:00:00  27.0    Male        Sweden
# 7             8  2021-02-02 00:00:00  23.0    Male           USA
# 8             9  2022-03-10 00:00:00  29.0  Female       Germany
# 9            10  2022-03-11 00:00:00  21.0    Male       Germany
# 10           11  2022-03-12 00:00:00   NaN    Male        Brazil
# 11           12  2022-03-13 00:00:00  31.0  Female           USA
# 12           13  2022-03-14 00:00:00  32.0    Male         India
# 13           14              3-15-21  27.0    Male         Chile
# 14           15  2022-03-16 00:00:00  23.0  Female  Saudi Arabia
# 15           16  2022-03-17 00:00:00  26.0    Male         India
# 16           17  2022-03-18 00:00:00  29.0  Female         Chile
# 17           18  2022-03-19 00:00:00   NaN    Male  Saudi Arabia
# 18           19  2022-03-20 00:00:00  35.0    Male         India
# 19           20  2022-03-21 00:00:00  38.0  Female            US
#
#     item purchased   value  monthly visits
# 0              2.0   258.0      234.000000
# 1              5.0   645.0      567.000000
# 2              2.0   258.0      123.000000
# 3              7.0   903.0      123.000000
# 4              1.0   129.0       47.000000
# 5              9.0  1161.0        3.000000
# 6              2.0   258.0      557.000000
# 7              1.0   129.0      455.000000
# 8              2.0   258.0      355.423077
# 9              6.0   774.0      554.000000
# 10             5.0   645.0      397.000000
# 11             4.0   516.0      567.000000
# 12             2.0   258.0      347.000000
# 13             3.0   387.0      355.423077
# 14             6.0   774.0      582.000000
# 15             7.0   903.0      234.000000
# 16             9.0  1161.0      355.423077
# 17             1.0   129.0      234.000000
# 18             6.0   774.0      478.000000
# 19             2.0   258.0      490.000000
